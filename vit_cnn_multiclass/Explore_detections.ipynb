# %%
script = False

import numpy as np
import pandas as pd
import os.path

from PIL import Image, ImageOps
from astropy.io import fits
from astropy.visualization import make_lupton_rgb
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
def make_plot_all(objects, data):
    for i in range(len(objects)):
        #if(i==500): break
        if(i%4 == 0):
            plt.figure(figsize=(12,8))
            for j in range(4):
                if(i+j > len(objects)-1): break
                plt.subplot(1,4,j+1)
                print(data['COADD_OBJECT_ID'].iloc[i+j])
                tmp_title = '{:.3f}'.format(data['Prob'].iloc[i+j])
                plt.title(tmp_title)
                rgb = make_lupton_rgb(objects[i+j][2], objects[i+j][1], objects[i+j][0], Q=11., stretch=40.)
                plt.imshow(rgb, aspect='equal')
                plt.xticks([], [])
                plt.yticks([], []) 
            if(script):
                plt.savefig(title+'_'+str(i+j), bbox_inches='tight')
                plt.close()
            else: 
                plt.show()

# %%
def explore(name, prob_lim, endname, N):
    print(N, name)
    with open('Y6_detections/' + name[:-5] + '.out') as f:
        lines = f.readlines()
        print(lines[2].rstrip('\n'))
        print(lines[3])
    filename = name[:-5] + endname
    path = '/Users/jimenagonzalez/research/DSPL/Searching-double-lenses/vit_cnn_multiclass/Y6_detections/'
    file_path = path + filename
    hdu_list = fits.open(file_path)
    images = hdu_list[1].data
    data = pd.DataFrame(hdu_list[2].data)
    #print(data.columns)
    data = data.astype({'COADD_OBJECT_ID': int, 'Prob': float})
    hdu_list.close()
    
    data = data[data['Prob'] > prob_lim]
    images = images[data.index.tolist()]
    print(len(data))
    make_plot_all(images, data)

# %%
#Labeled as positives
endname = ['_detections.fits', '_des', '_sdss', '_rest']
data = pd.read_csv('tiles_pd.csv')
N = 0
for index, row in data.iterrows():
    if(index < 207 + 165 + 165): continue
    name = row['tile']
    prob_lim = 0.9
    if(not os.path.isfile('Y6_detections/' + name[:-5] + '_detections.fits')):
        continue
    N += 1
    explore(name, prob_lim, endname[0], N)
# Out:
# 1 DES0029-2415.fits
# 24960
# Found 1 single lenses in this tile.
#
# 1
# 1072322115
# 2 DES0029-2623.fits
# 23905
# Found 1 single lenses in this tile.
#
# 1
# 1073483757
# 3 DES0029-2915.fits
# 23321
# Found 1 single lenses in this tile.
#
# 1
# 1073645987
# 4 DES0029-2958.fits
# 24363
# Found 2 single lenses in this tile.
#
# 2
# 1072671140
# 1072710765
# 5 DES0029-3332.fits
# 25047
# Found 2 single lenses in this tile.
#
# 2
# 1073601232
# 1073621774
# 6 DES0029-3415.fits
# 23058
# Found 4 single lenses in this tile.
#
# 4
# 1072823968
# 1072852705
# 1072824119
# 1072842612
# 7 DES0029-3457.fits
# 23438
# Found 2 single lenses in this tile.
#
# 2
# 1074059502
# 1074066075
# 8 DES0029-3540.fits
# 24782
# Found 2 single lenses in this tile.
#
# 2
# 1072607033
# 1072625623
# 9 DES0029-4123.fits
# 23303
# Found 2 single lenses in this tile.
#
# 2
# 1072207250
# 1072220670
# 10 DES0029-4206.fits
# 23381
# Found 3 single lenses in this tile.
#
# 3
# 1072926724
# 1072865496
# 1072880518
# 11 DES0029-4249.fits
# 22228
# Found 1 single lenses in this tile.
#
# 1
# 1072438583
# 12 DES0029-4706.fits
# 22825
# Found 4 single lenses in this tile.
#
# 4
# 1072572430
# 1073016269
# 1072588079
# 1073007493
# 13 DES0029-4748.fits
# 23527
# Found 6 single lenses in this tile.
#
# 6
# 1073887398
# 1074442065
# 1073885081
# 1073871226
# 1074424975
# 1074441628
# 14 DES0029-5040.fits
# 20654
# Found 2 single lenses in this tile.
#
# 2
# 1074249428
# 1074249935
# 15 DES0029-5331.fits
# 23720
# Found 7 single lenses in this tile.
#
# 7
# 1073674243
# 1073712334
# 1073742459
# 1073709254
# 1073685491
# 1073722928
# 1073725971
# 16 DES0029-5540.fits
# 23350
# Found 3 single lenses in this tile.
#
# 3
# 1072931298
# 1072948889
# 1072972727
# 17 DES0029-5748.fits
# 23845
# Found 5 single lenses in this tile.
#
# 5
# 1073390772
# 1073391055
# 1073380013
# 1073394138
# 1073419596
# 18 DES0029-6122.fits
# 22836
# Found 3 single lenses in this tile.
#
# 3
# 1073280933
# 1073283706
# 1073313078
# 19 DES0030-0541.fits
# 21266
# Found 1 single lenses in this tile.
#
# 1
# 1074298298
# 20 DES0030-0624.fits
# 23532
# Found 3 single lenses in this tile.
#
# 3
# 1073822199
# 1073815254
# 1073823896
# 21 DES0030-2332.fits
# 24922
# Found 3 single lenses in this tile.
#
# 3
# 1074097336
# 1074102999
# 1074077926
# 22 DES0030-2541.fits
# 23660
# Found 3 single lenses in this tile.
#
# 3
# 1074835765
# 1074528623
# 1074813660
# 23 DES0030-3206.fits
# 23803
# Found 4 single lenses in this tile.
#
# 4
# 1074741919
# 1074779705
# 1074736295
# 1074743682
# 24 DES0030-3249.fits
# 25279
# Found 1 single lenses in this tile.
#
# 1
# 1073524797
# 25 DES0030-4331.fits
# 22214
# Found 2 single lenses in this tile.
#
# 2
# 1073109652
# 1073085156
# 26 DES0030-4414.fits
# 25187
# Found 2 single lenses in this tile.
#
# 2
# 1075990880
# 1075979275
# 27 DES0030-4831.fits
# 23703
# Found 1 single lenses in this tile.
#
# 1
# 1074961705
# 28 DES0030-5123.fits
# 21776
# Found 6 single lenses in this tile.
#
# 6
# 1074459578
# 1074480064
# 1074507882
# 1074492455
# 1074477477
# 1074454732
# 29 DES0030-5957.fits
# 24750
# Found 10 single lenses in this tile.
#
# 10
# 1074393665
# 1074382278
# 1074346962
# 1074382879
# 1074404867
# 1074363626
# 1074409018
# 1074386565
# 1074343012
# 1074354172
# 30 DES0030-6456.fits
# 24103
# Found 3 single lenses in this tile.
#
# 3
# 1074552744
# 1074282715
# 1074281331
# 31 DES0031+0001.fits
# 24306
# Found 2 single lenses in this tile.
#
# 2
# 1074590504
# 1074628101
# 32 DES0031-0041.fits
# 23975
# Found 3 single lenses in this tile.
#
# 3
# 1074880927
# 1074861582
# 1074871339
# 33 DES0031-0124.fits
# 22512
# Found 1 single lenses in this tile.
#
# 1
# 1075381965
# 34 DES0031+0126.fits
# 25652
# Found 1 single lenses in this tile.
#
# 1
# 1076884087
# 35 DES0031-0207.fits
# 24207
# Found 3 single lenses in this tile.
#
# 3
# 1075481637
# 1075466531
# 1075472646
# 36 DES0031+0209.fits
# 23688
# Found 1 single lenses in this tile.
#
# 1
# 1077055798
# 37 DES0031-0250.fits
# 23943
# Found 2 single lenses in this tile.
#
# 2
# 1075560206
# 1075546877
# 38 DES0031-0333.fits
# 24108
# Found 1 single lenses in this tile.
#
# 1
# 1076214478
# 39 DES0031-0707.fits
# 19420
# Found 3 single lenses in this tile.
#
# 3
# 1073039944
# 1073033675
# 1073056487
# 40 DES0031-2249.fits
# 25052
# Found 2 single lenses in this tile.
#
# 2
# 1074702625
# 1074707226
# 41 DES0031-2749.fits
# 21951
# Found 1 single lenses in this tile.
#
# 1
# 1075295306
# 42 DES0031-3123.fits
# 23600
# Found 7 single lenses in this tile.
#
# 7
# 1075114367
# 1075083390
# 1075088914
# 1075064256
# 1075097987
# 1075087046
# 1074662153
# 43 DES0031-4457.fits
# 23849
# Found 3 single lenses in this tile.
#
# 3
# 1075778153
# 1075797194
# 1075815412
# 44 DES0031-4540.fits
# 23840
# Found 4 single lenses in this tile.
#
# 4
# 1075621940
# 1075643837
# 1075651867
# 1075672258
# 45 DES0031-5205.fits
# 22552
# Found 1 single lenses in this tile.
#
# 1
# 1076135976
# 46 DES0031-5414.fits
# 23362
# Found 3 single lenses in this tile.
#
# 3
# 1075251947
# 1075245020
# 1075244930
# 47 DES0032+0418.fits
# 24497
# Found 4 single lenses in this tile.
#
# 4
# 1075754271
# 1075753417
# 1075756943
# 1075726211
# 48 DES0032+0500.fits
# 21523
# Found 1 single lenses in this tile.
#
# 1
# 1074921941
# 49 DES0032-2415.fits
# 22807
# Found 1 single lenses in this tile.
#
# 1
# 1077400486
